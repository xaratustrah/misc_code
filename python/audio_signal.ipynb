# %% [markdown]
# # Audio Signal with Hilbert Plot

# %%
import numpy as np
from scipy.signal import hilbert, butter, filtfilt
import matplotlib.pyplot as plt
from scipy.io.wavfile import write
from pylab import psd,specgram
# %matplotlib inline
import EMD
from iqtools import *

# %%
fs = 11025
t, x = make_signal(440, fs, noise = False, nharm = 2)

# %%
write('out.wav', fs, x)

# %%
npoints = 10000
plt.subplot(221)
plt.plot(t[0:npoints], x[0:npoints])
plt.subplot(222)
plot_hilbert(x)
plt.figure()
#Pxx, freqs = psd(x, Fs = fs, noverlap=0)
plot_fft(x, fs, 0)
# Out:
# (array([ 0.,  1.,  2., ..., -3., -2., -1.]),
#  array([ -1.05039328e-15 +0.00000000e+00j,
#           1.05519352e-15 +4.53281883e-17j,
#           3.49136140e-15 -1.75936649e-15j, ...,
#           2.92821007e-15 -8.14291209e-16j,
#           3.49136140e-15 +1.75936649e-15j,   1.05519352e-15 -4.53281883e-17j]))

# %%
b, a = butter(8, 0.1)
y = filtfilt(b, a, x, padlen = 150)
pxx, freq = psd (y, NFFT = 256, Fs = fs, noverlap = 256)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-10-d2d943562b99> in <module>()
#       1 b, a = butter(8, 0.1)
#       2 y = filtfilt(b, a, x, padlen = 150)
# ----> 3 pxx, freq = psd (y, NFFT = 256, Fs = fs, noverlap = 256)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/pyplot.py in psd(x, NFFT, Fs, Fc, detrend, window, noverlap, pad_to, sides, scale_by_freq, hold, **kwargs)
#    3027         ret = ax.psd(x, NFFT=NFFT, Fs=Fs, Fc=Fc, detrend=detrend,
#    3028                      window=window, noverlap=noverlap, pad_to=pad_to,
# -> 3029                      sides=sides, scale_by_freq=scale_by_freq, **kwargs)
#    3030         draw_if_interactive()
#    3031     finally:
#
# ...

# %%
imfs = EMD.emd(x)

# %%
fig, axs = plt.subplots(3,4, figsize=(15, 6), facecolor='w', edgecolor='k')
#fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()
for i in range(np.shape(imfs)[1]):

    axs[i].plot(imfs[:,i])
    axs[i].set_title("IMF{}".format(i))

# %%
for i in range (1,np.shape(imfs)[1]):
    plt.subplot(4, 4, i)
    plot_hilbert(imfs[:,i])

# %%
plt.plot(np.sin(np.linspace(0,10,1000)))

# %%
from pylab import *

# %%
plot(sin(linspace(0,10,1000)))

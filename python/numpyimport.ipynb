# %%
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_data = np.genfromtxt('data', delimiter='\t', names=None, dtype=float, deletechars='', replace_space='', skip_header=1)

# %%
my_data
# Out:
# array([[  5.68700000e+01,   6.57600000e+01,   5.43876500e+02,
#           8.76432000e+02,   8.76543877e+05],
#        [  8.76987000e+02,   7.60000000e+01,   4.30000000e+01,
#           9.80000000e+01,   1.20000000e+01],
#        [  9.00000000e+00,   8.70000000e+01,   5.43000000e+02,
#           2.10000000e+01,   4.56000000e+02]])

# %%
my_data.dtype.names[0]
# Out:
# 'Blah'

# %%
plt.plot(my_data[my_data.dtype.names[0]])

# %%
my_data
# Out:
# array([(56.87, 65.76, 543.8765, 876.432, 876543.8765),
#        (876.987, 76.0, 43.0, 98.0, 12.0), (9.0, 87.0, 543.0, 21.0, 456.0)],
#       dtype=[('Blah', '<f8'), ('bloops', '<f8'), ('foo', '<f8'), ('bar', '<f8'), ('ba_z', '<f8')])

# %%
type(my_data)
# Out:
# numpy.ndarray

# %%
np.shape(my_data[0])
# Out:
# ()

# %%
my_data[0][1]
# Out:
# 65.760000000000005
